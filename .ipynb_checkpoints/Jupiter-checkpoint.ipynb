# %% [markdown]
# Primero importare todos los datos y les exlporare.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # es para enseñar todas las columnas del df

# %%
ori_actor=pd.read_csv('data/actor.csv')
ori_category=pd.read_csv('data/category.csv')
ori_film=pd.read_csv('data/film.csv')
ori_inventory=pd.read_csv('data/inventory.csv')
ori_language=pd.read_csv('data/language.csv')
ori_rental=pd.read_csv('data/rental.csv')
ori_old_HDD=pd.read_csv('data/old_HDD.csv')

df_actor=ori_actor.copy()
df_category=ori_category.copy()
df_film=ori_film.copy()
df_inventory=ori_inventory.copy()
df_language=ori_language.copy()
df_rental=ori_rental.copy()
df_old_HDD=ori_old_HDD.copy()

# %%
df_actor
# Out:
#      actor_id first_name     last_name          last_update
# 0           1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2           3         ED         CHASE  2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33
# ..        ...        ...           ...                  ...
# 195       196       BELA        WALKEN  2006-02-15 04:34:33
# 196       197      REESE          WEST  2006-02-15 04:34:33
# 197       198       MARY        KEITEL  2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT  2006-02-15 04:34:33
# 199       200      THORA        TEMPLE  2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
df_actor.drop('actor_id', inplace=True, axis=1)

# %%
df_actor.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df_actor.dtypes
# Out:
# first_name     object
# last_name      object
# last_update    object
# dtype: object

# %%
df_actor.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   first_name   200 non-null    object
#  1   last_name    200 non-null    object
#  2   last_update  200 non-null    object
# dtypes: object(3)
# memory usage: 39.5 KB

# %%
df_actor.drop_duplicates(inplace=True)

# %% [markdown]
# actor.csv esta limpio. La fecha es siempre el mismo segundo parece que no es relevante

# %%
df_category
# Out:
#     category_id         name          last_update
# 0             1       Action  2006-02-15 04:46:27
# 1             2    Animation  2006-02-15 04:46:27
# 2             3     Children  2006-02-15 04:46:27
# 3             4     Classics  2006-02-15 04:46:27
# 4             5       Comedy  2006-02-15 04:46:27
# 5             6  Documentary  2006-02-15 04:46:27
# 6             7        Drama  2006-02-15 04:46:27
# 7             8       Family  2006-02-15 04:46:27
# 8             9      Foreign  2006-02-15 04:46:27
# 9            10        Games  2006-02-15 04:46:27
# 10           11       Horror  2006-02-15 04:46:27
# 11           12        Music  2006-02-15 04:46:27
# 12           13          New  2006-02-15 04:46:27
# 13           14       Sci-Fi  2006-02-15 04:46:27
# 14           15       Sports  2006-02-15 04:46:27
# 15           16       Travel  2006-02-15 04:46:27

# %%
df_category.dtypes
# Out:
# category_id     int64
# name           object
# last_update    object
# dtype: object

# %%
df_category.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
#  2   last_update  16 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.4 KB

# %% [markdown]
# category.csv esta limpio. La fecha vuelve a ser el mismo segundo, unos minutos despues que la tabla anterior parece que es la fecha de cuando se guardaron los datos. no es relevante para mi base de datos

# %%
df_film
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
df_film.language_id.unique()
# Out:
# array([1])

# %%
df_film.dtypes
# Out:
# film_id                   int64
# title                    object
# description              object
# release_year              int64
# language_id               int64
# original_language_id    float64
# rental_duration           int64
# rental_rate             float64
# length                    int64
# replacement_cost        float64
# rating                   object
# special_features         object
# last_update              object
# dtype: object

# %%
df_film.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film_id               1000 non-null   int64
#  1   title                 1000 non-null   object
#  2   description           1000 non-null   object
#  3   release_year          1000 non-null   int64
#  4   language_id           1000 non-null   int64
#  5   original_language_id  0 non-null      float64
#  6   rental_duration       1000 non-null   int64
#  7   rental_rate           1000 non-null   float64
#  8   length                1000 non-null   int64
#  9   replacement_cost      1000 non-null   float64
#  10  rating                1000 non-null   object
#  11  special_features      1000 non-null   object
#  12  last_update           1000 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 495.3 KB

# %% [markdown]
# Parece que la columna original_language_id esta vacia. Tendre que valorar quitarla o rellenarla dependiendo de los datos que encentre en las proximas tablas. La columna language_id es siempre la misma.
#
# Tambien parece que todos los años de estreno son 2006, ya bien puede ser un error o que esta base de datos este centrada en el año 2006

# %%
df_inventory
# Out:
#      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]

# %%
df_inventory.dtypes
# Out:
# inventory_id     int64
# film_id          int64
# store_id         int64
# last_update     object
# dtype: object

# %%
df_inventory.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 97.8 KB

# %%
df_language
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19
# 5            6    German  2006-02-15 05:02:19

# %%
df_language.dtypes
# Out:
# language_id     int64
# name           object
# last_update    object
# dtype: object

# %%
ori_rental
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
ori_rental.dtypes
# Out:
# rental_id        int64
# rental_date     object
# inventory_id     int64
# customer_id      int64
# return_date     object
# staff_id         int64
# last_update     object
# dtype: object

# %% [markdown]
# voy a rellenar la columna de original language en films de manera aleatoria con numeros del 1-6

# %%
df_film
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
import random

# %%
x = random.randint(1,6)
print(x)
# Out:
# 6

# %%
df_film2=df_film.copy()

# %%
df_film2.original_language_id=df_film2.original_language_id.apply(lambda x : random.randint(1,6))

# %%
df_film2
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
df_film2.dtypes
# Out:
# film_id                   int64
# title                    object
# description              object
# release_year              int64
# language_id               int64
# original_language_id      int64
# rental_duration           int64
# rental_rate             float64
# length                    int64
# replacement_cost        float64
# rating                   object
# special_features         object
# last_update              object
# dtype: object

# %%
df_old_HDD
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
len((df_old_HDD['first_name'] + ' ' + df_old_HDD['last_name']).unique())
# Out:
# 39

# %% [markdown]
# de los 200 actores solo conocemos en que peliculas han trabajado 39

# %%
(df_old_HDD['title'] + ' ' + str(df_old_HDD['category_id'])).unique()
# Out:
# array(['ACADEMY DINOSAUR 0       6\n1       2\n2      13\n3      10\n4      14\n       ..\n995     3\n996    14\n997    11\n998     9\n999    15\nName: category_id, Length: 1000, dtype: int64',
#        'ANACONDA CONFESSIONS 0       6\n1       2\n2      13\n3      10\n4      14\n       ..\n995     3\n996    14\n997    11\n998     9\n999    15\nName: category_id, Length: 1000, dtype: int64',
#        'ANGELS LIFE 0       6\n1       2\n2      13\n3      10\n4      14\n       ..\n995     3\n996    14\n997    11\n998     9\n999    15\nName: category_id, Length: 1000, dtype: int64',
#        'BULWORTH COMMANDMENTS 0       6\n1       2\n2      13\n3      10\n4      14\n       ..\n995     3\n996    14\n997    11\n998     9\n999    15\nName: category_id, Length: 1000, dtype: int64',
#        'CHEAPER CLYDE 0       6\n1       2\n2      13\n3      10\n4      14\n       ..\n995     3\n996    14\n997    11\n998     9\n999    15\nName: category_id, Length: 1000, dtype: int64',
# ...

# %%
len((df_old_HDD['title'] + ' ' + str(df_old_HDD['category_id'])).unique())
# Out:
# 614

# %%
len(((df_old_HDD['title'])).unique())
# Out:
# 614

# %% [markdown]
# solo hay 614 peliculas de las que conocemos su categoria y ninguna tiene mas de una categoria.

# %% [markdown]
# dado que en el disco duro utiliza el nombre y apellido de los actores y no su id, el primary key de la tabla de actores debera ser su nombre y apellidos

# %%
df_actor["coplete_name"]=(df_actor['first_name'] + ' ' + df_actor['last_name'])

# %%
df_actor
# Out:
#     first_name     last_name          last_update         coplete_name
# 0     PENELOPE       GUINESS  2006-02-15 04:34:33     PENELOPE GUINESS
# 1         NICK      WAHLBERG  2006-02-15 04:34:33        NICK WAHLBERG
# 2           ED         CHASE  2006-02-15 04:34:33             ED CHASE
# 3     JENNIFER         DAVIS  2006-02-15 04:34:33       JENNIFER DAVIS
# 4       JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33  JOHNNY LOLLOBRIGIDA
# ..         ...           ...                  ...                  ...
# 195       BELA        WALKEN  2006-02-15 04:34:33          BELA WALKEN
# 196      REESE          WEST  2006-02-15 04:34:33           REESE WEST
# 197       MARY        KEITEL  2006-02-15 04:34:33          MARY KEITEL
# 198      JULIA       FAWCETT  2006-02-15 04:34:33        JULIA FAWCETT
# 199      THORA        TEMPLE  2006-02-15 04:34:33         THORA TEMPLE
#
# [199 rows x 4 columns]

# %% [markdown]
# y hare lo mismo con la tabla del disco duro

# %%
df_old_HDD["coplete_name"]=(df_old_HDD['first_name'] + ' ' + df_old_HDD['last_name'])

# %%
df_old_HDD
# Out:
#     first_name last_name                  title  release_year  category_id  \
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
#          coplete_name
# 0    PENELOPE GUINESS
# ...

# %% [markdown]
# en la tabla de rental hay inventory_id de mas de 1000 mientras que la tabla de inventory solo hay de 1-1000
# sobreescribire la columna para que euqde con valores de 1-1000

# %%
df_rental
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
df_rental.inventory_id=df_rental.inventory_id.apply(lambda x : random.randint(1,1000))

# %%
df_rental
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           824          130
# 1            2  2005-05-24 22:54:33           223          459
# 2            3  2005-05-24 23:03:39           280          408
# 3            4  2005-05-24 23:04:41           422          333
# 4            5  2005-05-24 23:05:21           959          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25           519          216
# 996        998  2005-05-31 00:16:57           434          389
# 997        999  2005-05-31 00:25:10           186          413
# 998       1000  2005-05-31 00:25:56           793          332
# 999       1001  2005-05-31 00:46:31           278           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
crea_db=conn.connect(host='localhost', user='root', passwd='admin')

cursor=crea_db.cursor()

cursor.execute('drop database if exists VideoClub;')
cursor.execute('create database VideoClub;')

# %%
db=conn.connect(host='localhost', user='root', passwd='admin', database='VideoClub')

cursor=db.cursor()

# %%
df_actor
# Out:
#     first_name     last_name          last_update         coplete_name
# 0     PENELOPE       GUINESS  2006-02-15 04:34:33     PENELOPE GUINESS
# 1         NICK      WAHLBERG  2006-02-15 04:34:33        NICK WAHLBERG
# 2           ED         CHASE  2006-02-15 04:34:33             ED CHASE
# 3     JENNIFER         DAVIS  2006-02-15 04:34:33       JENNIFER DAVIS
# 4       JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33  JOHNNY LOLLOBRIGIDA
# ..         ...           ...                  ...                  ...
# 195       BELA        WALKEN  2006-02-15 04:34:33          BELA WALKEN
# 196      REESE          WEST  2006-02-15 04:34:33           REESE WEST
# 197       MARY        KEITEL  2006-02-15 04:34:33          MARY KEITEL
# 198      JULIA       FAWCETT  2006-02-15 04:34:33        JULIA FAWCETT
# 199      THORA        TEMPLE  2006-02-15 04:34:33         THORA TEMPLE
#
# [199 rows x 4 columns]

# %%
cursor.execute('drop table if exists actores;')



tabla='''

        create table actores (
            
            first_name varchar(50),
            last_name varchar(50),
            last_update varchar(50),
            coplete_name varchar(50) primary key
            
        );

'''


cursor.execute(tabla)

# %%
# check

cursor.execute('show tables;')

for x in cursor:
    print(x)
# Out:
# ('actores',)
# ('category',)

# %%
for i in range(len(df_actor)):
    
    insert_query=f"insert into actores ({','.join(df_actor.columns)}) values {tuple(df_actor.iloc[i].values)};"
    
    
    cursor.execute(insert_query)
    
    
db.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
#       1 for i in range(len(df_actor)):
#       3     insert_query=f"insert into actores ({','.join(df_actor.columns)}) values {tuple(df_actor.iloc[i].values)};"
# ----> 6     cursor.execute(insert_query)
#       9 db.commit()
#
# File /opt/homebrew/lib/python3.9/site-packages/mysql/connector/cursor.py:572, in MySQLCursor.execute(self, operation, params, multi)
#     569     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     571 try:
# --> 572     self._handle_result(self._connection.cmd_query(stmt))
#     573 except errors.InterfaceError:
#     574     if self._connection._have_next_result:  # pylint: disable=W0212
#
# File /opt/homebrew/lib/python3.9/site-packages/mysql/connector/connection.py:920, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
df_category
# Out:
#     category_id         name          last_update
# 0             1       Action  2006-02-15 04:46:27
# 1             2    Animation  2006-02-15 04:46:27
# 2             3     Children  2006-02-15 04:46:27
# 3             4     Classics  2006-02-15 04:46:27
# 4             5       Comedy  2006-02-15 04:46:27
# 5             6  Documentary  2006-02-15 04:46:27
# 6             7        Drama  2006-02-15 04:46:27
# 7             8       Family  2006-02-15 04:46:27
# 8             9      Foreign  2006-02-15 04:46:27
# 9            10        Games  2006-02-15 04:46:27
# 10           11       Horror  2006-02-15 04:46:27
# 11           12        Music  2006-02-15 04:46:27
# 12           13          New  2006-02-15 04:46:27
# 13           14       Sci-Fi  2006-02-15 04:46:27
# 14           15       Sports  2006-02-15 04:46:27
# 15           16       Travel  2006-02-15 04:46:27

# %%
cursor.execute('drop table if exists category;')



tabla='''

        create table category (
            
            category_id int primary key,
            name varchar(50),
            last_update varchar(50)
           
            
        );

'''


cursor.execute(tabla)

# %%
for i in range(len(df_category)):
    
    insert_query=f"insert into category ({','.join(df_category.columns)}) values {tuple(df_category.iloc[i].values)};"
    
    
    cursor.execute(insert_query)
    
    
db.commit()

# %%
df_film2
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
cursor.execute('drop table if exists films;')



tabla='''

        create table films (
            
            film_id int,
            title varchar(50) primary key,
            description varchar(200),
            release_year int,
            language_id int,
            original_language_id int,
            rental_duration int,
            rental_rate float,
            length int,
            replacement_cost float,
            rating varchar(50),
            special_features varchar(200),
            last_update varchar(50)
        );

'''


cursor.execute(tabla)

# %%
for i in range(len(df_film2)):
    
    insert_query=f"insert into films ({','.join(df_film2.columns)}) values {tuple(df_film2.iloc[i].values)};"
    
    
    cursor.execute(insert_query)
    
    
db.commit()

# %%
df_inventory
# Out:
#      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]

# %%
cursor.execute('drop table if exists inventory;')



tabla='''

        create table inventory (
            
            inventory_id int primary key,
            film_id int,
            store_id int,
            last_update varchar(50)
            
        );

'''


cursor.execute(tabla)

# %%
for i in range(len(df_inventory)):
    
    insert_query=f"insert into inventory ({','.join(df_inventory.columns)}) values {tuple(df_inventory.iloc[i].values)};"
    
    
    cursor.execute(insert_query)
    
    
db.commit()

# %%
df_language
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19
# 5            6    German  2006-02-15 05:02:19

# %%
cursor.execute('drop table if exists language;')



tabla='''

        create table language (
            
            language_id int primary key,
            name varchar(50),
            last_update varchar(50)
            
        );

'''


cursor.execute(tabla)

# %%
for i in range(len(df_language)):
    
    insert_query=f"insert into language ({','.join(df_language.columns)}) values {tuple(df_language.iloc[i].values)};"
    
    
    cursor.execute(insert_query)
    
    
db.commit()

# %%
df_rental
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           824          130
# 1            2  2005-05-24 22:54:33           223          459
# 2            3  2005-05-24 23:03:39           280          408
# 3            4  2005-05-24 23:04:41           422          333
# 4            5  2005-05-24 23:05:21           959          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25           519          216
# 996        998  2005-05-31 00:16:57           434          389
# 997        999  2005-05-31 00:25:10           186          413
# 998       1000  2005-05-31 00:25:56           793          332
# 999       1001  2005-05-31 00:46:31           278           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
cursor.execute('drop table if exists rental;')



tabla='''

        create table rental (
            
            rental_id int primary key,
            rental_date varchar(50),
            inventory_id int,
            customer_id int,
            return_date varchar(50),
            staff_id int,
            last_update varchar(50)
            
        );

'''


cursor.execute(tabla)

# %%
for i in range(len(df_rental)):
    
    insert_query=f"insert into rental ({','.join(df_rental.columns)}) values {tuple(df_rental.iloc[i].values)};"
    
    
    cursor.execute(insert_query)
    
    
db.commit()

# %%
df_old_HDD.head(1)
# Out:
#   first_name last_name             title  release_year  category_id  \
# 0   PENELOPE   GUINESS  ACADEMY DINOSAUR          2006            6
#
#        coplete_name
# 0  PENELOPE GUINESS

# %%
cursor.execute('drop table if exists HDD;')



tabla='''

        create table HDD (
            
            first_name varchar(50),
            last_name varchar(50),
            title varchar(50),
            release_year int,
            category_id int,
            coplete_name varchar(50)
            
        );

'''


cursor.execute(tabla)

# %%
for i in range(len(df_old_HDD)):
    
    insert_query=f"insert into HDD ({','.join(df_old_HDD.columns)}) values {tuple(df_old_HDD.iloc[i].values)};"
    
    
    cursor.execute(insert_query)
    
    
db.commit()
